# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
shark = pd.read_csv(r"C:/Users/Marco/Desktop/IronHack/projects/Project_1/data/attacks.csv", encoding='latin1')
shark
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# 2               Hawaii                    Habush, Oahu      Surfing
# 3      New South Wales              Arrawarra Headland      Surfing
# 4               Colima                        La Ticla  Free diving
# ...                ...                             ...          ...
# 25718              NaN                             NaN          NaN
# 25719              NaN                             NaN          NaN
# 25720              NaN                             NaN          NaN
# 25721              NaN                             NaN          NaN
# 25722              NaN                             NaN          NaN
#
#                   Name Sex   ...         Species   \
# 0          Julie Wolfe    F  ...      White shark
# 1      Adyson McNeely     F  ...              NaN
# 2          John Denges    M  ...              NaN
# 3                 male    M  ...        2 m shark
# 4       Gustavo Ramos     M  ...  Tiger shark, 3m
# ...                ...  ...  ...              ...
# 25718              NaN  NaN  ...              NaN
# 25719              NaN  NaN  ...              NaN
# 25720              NaN  NaN  ...              NaN
# 25721              NaN  NaN  ...              NaN
# 25722              NaN  NaN  ...              NaN
#
#                Investigator or Source                       pdf  \
# 0                    R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1      K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2      K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3                      B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4                           A .Kipper      2018.06.04-Ramos.pdf
# ...                               ...                       ...
# 25718                             NaN                       NaN
# 25719                             NaN                       NaN
# 25720                             NaN                       NaN
# 25721                             NaN                       NaN
# 25722                             NaN                       NaN
#
#                                             href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 25718                                                NaN
# 25719                                                NaN
# 25720                                                NaN
# 25721                                                NaN
# 25722                                                NaN
#
#                                                     href Case Number.1  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                  ...           ...
# 25718                                                NaN           NaN
# 25719                                                NaN           NaN
# 25720                                                NaN           NaN
# 25721                                                NaN           NaN
# 25722                                                NaN           NaN
#
#       Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0        2018.06.25         6303.0         NaN         NaN
# 1        2018.06.18         6302.0         NaN         NaN
# 2        2018.06.09         6301.0         NaN         NaN
# 3        2018.06.08         6300.0         NaN         NaN
# 4        2018.06.04         6299.0         NaN         NaN
# ...             ...            ...         ...         ...
# 25718           NaN            NaN         NaN         NaN
# 25719           NaN            NaN         NaN         NaN
# 25720           NaN            NaN         NaN         NaN
# 25721           NaN            NaN         NaN         NaN
# 25722           NaN            NaN         NaN         NaN
#
# [25723 rows x 24 columns]

# %%
"""
Starting with the data visualization to get a general idea of what
i am looking at, such as the column names. This way i can select my
4 questions for my investigation.

"""
# Out:
# '\nStarting with the data visualization to get a general idea of what\ni am looking at, such as the column names. This way i can select my\n4 questions for my investigation.\n\n'

# %%
shark.info
# Out:
# <bound method DataFrame.info of       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# 2               Hawaii                    Habush, Oahu      Surfing
# 3      New South Wales              Arrawarra Headland      Surfing
# 4               Colima                        La Ticla  Free diving
# ...                ...                             ...          ...
# 25718              NaN                             NaN          NaN
# 25719              NaN                             NaN          NaN
# 25720              NaN                             NaN          NaN
# 25721              NaN                             NaN          NaN
# 25722              NaN                             NaN          NaN
#
#                   Name Sex   ...         Species   \
# 0          Julie Wolfe    F  ...      White shark
# 1      Adyson McNeely     F  ...              NaN
# 2          John Denges    M  ...              NaN
# 3                 male    M  ...        2 m shark
# 4       Gustavo Ramos     M  ...  Tiger shark, 3m
# ...                ...  ...  ...              ...
# 25718              NaN  NaN  ...              NaN
# 25719              NaN  NaN  ...              NaN
# 25720              NaN  NaN  ...              NaN
# 25721              NaN  NaN  ...              NaN
# 25722              NaN  NaN  ...              NaN
#
#                Investigator or Source                       pdf  \
# 0                    R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1      K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2      K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3                      B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4                           A .Kipper      2018.06.04-Ramos.pdf
# ...                               ...                       ...
# 25718                             NaN                       NaN
# 25719                             NaN                       NaN
# 25720                             NaN                       NaN
# 25721                             NaN                       NaN
# 25722                             NaN                       NaN
#
#                                             href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 25718                                                NaN
# 25719                                                NaN
# 25720                                                NaN
# 25721                                                NaN
# 25722                                                NaN
#
#                                                     href Case Number.1  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                  ...           ...
# 25718                                                NaN           NaN
# 25719                                                NaN           NaN
# 25720                                                NaN           NaN
# 25721                                                NaN           NaN
# 25722                                                NaN           NaN
#
#       Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0        2018.06.25         6303.0         NaN         NaN
# 1        2018.06.18         6302.0         NaN         NaN
# 2        2018.06.09         6301.0         NaN         NaN
# 3        2018.06.08         6300.0         NaN         NaN
# 4        2018.06.04         6299.0         NaN         NaN
# ...             ...            ...         ...         ...
# 25718           NaN            NaN         NaN         NaN
# 25719           NaN            NaN         NaN         NaN
# 25720           NaN            NaN         NaN         NaN
# 25721           NaN            NaN         NaN         NaN
# 25722           NaN            NaN         NaN         NaN
#
# [25723 rows x 24 columns]>

# %%
shark.shape
# Out:
# (25723, 24)

# %%
shark.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
shark.nunique()
# Out:
# Case Number               6287
# Date                      5433
# Year                       249
# Type                         8
# Country                    212
# Area                       825
# Location                  4108
# Activity                  1532
# Name                      5230
# Sex                          6
# Age                        157
# Injury                    3737
# Fatal (Y/N)                  8
# Time                       366
# Species                   1549
# Investigator or Source    4969
# pdf                       6291
# href formula              6290
# href                      6285
# Case Number.1             6285
# Case Number.2             6286
# original order            6308
# Unnamed: 22                  1
# Unnamed: 23                  2
# dtype: int64

# %%
"""
After looking at some parts of the dataset, i have decided my
questions will be:
1.Which gender is tastier? (sex, column)
2.Have sharks entered a pro-vegan movement? (year, column)
3.Do sharks procrastinate their lunch-time? (Time, column)
4.Do sharks like to bully humans? (fatal, injury, columns)

"""
# Out:
# '\nAfter looking at some parts of the dataset, i have decided my\nquestions will be:\n1.Which gender is tastier? (sex, column)\n2.Have sharks entered a pro-vegan movement? (year, column)\n3.Do sharks procrastinate their lunch-time? (Time, column)\n4.Do sharks like to bully humans? (fatal, injury, columns)\n\n'

# %%
shark.dropna(subset=['Year', 'Time', 'Sex ', 'Activity', 'Fatal (Y/N)', 'Injury'], inplace=True)
#eliminating all the missing values from the columns i will use

# %%
shark.rename(columns={'Sex ': 'Sex'}, inplace=True)
#changing the sex column name because it had an unnecessary space at the end

# %%
used_columns = ['Year', 'Time', 'Sex', 'Activity', 'Fatal (Y/N)', 'Injury']
shark_columns = shark[used_columns]
#creating a new data frame with only the columns i need for my investigation

# %%
shark_columns
# Out:
#         Year            Time Sex  \
# 0     2018.0           18h00   F
# 1     2018.0   14h00  -15h00   F
# 2     2018.0           07h45   M
# 6     2018.0  Late afternoon   M
# 8     2018.0           17h00   M
# ...      ...             ...  ..
# 6228     0.0         Morning   F
# 6241     0.0       Afternoon   M
# 6242     0.0       Afternoon   M
# 6243     0.0       Afternoon   M
# 6265     0.0       Afternoon   M
#
#                                                Activity Fatal (Y/N)  \
# 0                                              Paddling           N
# 1                                              Standing           N
# 2                                               Surfing           N
# 6                                              Swimming           Y
# 8                                               Walking           N
# ...                                                 ...         ...
# 6228                                        Free diving           N
# 6241  Fishing from a small boat & put his hand in th...           N
# 6242  Swimming naked near a date palm where many dat...           N
# 6243  Swimming in section of river used for washing ...           N
# 6265                                           Swimming           Y
#
#                                                  Injury
# 0     No injury to occupant, outrigger canoe and pad...
# 1                            Minor injury to left thigh
# 2          Injury to left lower leg from surfboard skeg
# 6                                                 FATAL
# 8                                 Lower left leg bitten
# ...                                                 ...
# 6228                Shoulder scratched, swim fin bitten
# 6241                                 Right hand severed
# 6242                                        Arm severed
# 6243         Right leg lacerated & surgically amputated
# 6265      FATAL, left leg bitten with severe blood loss
#
# [2653 rows x 6 columns]

# %%
shark_columns = shark_columns[shark_columns['Year'] > 1000] 
#I am taking out any year that is smaller than 1000 to take out from the year column wrong data

# %%
shark_columns
# Out:
#         Year            Time Sex          Activity Fatal (Y/N)  \
# 0     2018.0           18h00   F          Paddling           N
# 1     2018.0   14h00  -15h00   F          Standing           N
# 2     2018.0           07h45   M           Surfing           N
# 6     2018.0  Late afternoon   M          Swimming           Y
# 8     2018.0           17h00   M           Walking           N
# ...      ...             ...  ..               ...         ...
# 6105  1826.0     19h00-20h00   M  Jumped overboard           Y
# 6113  1817.0         Evening   M          Swimming           Y
# 6114  1817.0         Evening   M          Swimming           Y
# 6115  1817.0           13h00   M       Conch diver           N
# 6160  1703.0           Night   M          Swimming           N
#
#                                                  Injury
# 0     No injury to occupant, outrigger canoe and pad...
# 1                            Minor injury to left thigh
# 2          Injury to left lower leg from surfboard skeg
# 6                                                 FATAL
# 8                                 Lower left leg bitten
# ...                                                 ...
# 6105                                              FATAL
# 6113                                              FATAL
# 6114                                              FATAL
# 6115                                     Abdomen bitten
# 6160  Hand and foot severely bitten, surgically ampu...
#
# [2647 rows x 6 columns]

# %%
#to now do all the cleaning loc function is required to not;
#the original data set and to not get the error 'setting with copy warning'

# %%
shark_columns.loc[shark['Sex'].isin(['M', 'F']), 'Sex'] = shark_columns['Sex'].replace({'M': 'Male', 'F': 'Female'})
#changing the original dataframe, to make it more readable i change the f by female and M by Male

# %%
shark_columns
# Out:
#         Year            Time     Sex          Activity Fatal (Y/N)  \
# 0     2018.0           18h00  Female          Paddling           N
# 1     2018.0   14h00  -15h00  Female          Standing           N
# 2     2018.0           07h45    Male           Surfing           N
# 6     2018.0  Late afternoon    Male          Swimming           Y
# 8     2018.0           17h00    Male           Walking           N
# ...      ...             ...     ...               ...         ...
# 6105  1826.0     19h00-20h00    Male  Jumped overboard           Y
# 6113  1817.0         Evening    Male          Swimming           Y
# 6114  1817.0         Evening    Male          Swimming           Y
# 6115  1817.0           13h00    Male       Conch diver           N
# 6160  1703.0           Night    Male          Swimming           N
#
#                                                  Injury
# 0     No injury to occupant, outrigger canoe and pad...
# 1                            Minor injury to left thigh
# 2          Injury to left lower leg from surfboard skeg
# 6                                                 FATAL
# 8                                 Lower left leg bitten
# ...                                                 ...
# 6105                                              FATAL
# 6113                                              FATAL
# 6114                                              FATAL
# 6115                                     Abdomen bitten
# 6160  Hand and foot severely bitten, surgically ampu...
#
# [2647 rows x 6 columns]

# %%
shark_columns.loc[:, 'Activity'] = shark_columns['Activity'].str.lower()
#making all the answers of the activity column with no capitalaized letters in case there are any irregularities

# %%
shark_columns
# Out:
#         Year            Time     Sex          Activity Fatal (Y/N)  \
# 0     2018.0           18h00  Female          paddling           N
# 1     2018.0   14h00  -15h00  Female          standing           N
# 2     2018.0           07h45    Male           surfing           N
# 6     2018.0  Late afternoon    Male          swimming           Y
# 8     2018.0           17h00    Male           walking           N
# ...      ...             ...     ...               ...         ...
# 6105  1826.0     19h00-20h00    Male  jumped overboard           Y
# 6113  1817.0         Evening    Male          swimming           Y
# 6114  1817.0         Evening    Male          swimming           Y
# 6115  1817.0           13h00    Male       conch diver           N
# 6160  1703.0           Night    Male          swimming           N
#
#                                                  Injury
# 0     No injury to occupant, outrigger canoe and pad...
# 1                            Minor injury to left thigh
# 2          Injury to left lower leg from surfboard skeg
# 6                                                 FATAL
# 8                                 Lower left leg bitten
# ...                                                 ...
# 6105                                              FATAL
# 6113                                              FATAL
# 6114                                              FATAL
# 6115                                     Abdomen bitten
# 6160  Hand and foot severely bitten, surgically ampu...
#
# [2647 rows x 6 columns]

# %%
shark_columns_copy = shark_columns.copy()

shark_columns_copy['Year'] = shark_columns_copy['Year'].astype(str).str.split('.').str[0].astype(int)

#creating a copy due to error of modifying the original data frame
#converting all the data in the year column into integrers

# %%
shark_columns_copy
# Out:
#       Year            Time     Sex          Activity Fatal (Y/N)  \
# 0     2018           18h00  Female          paddling           N
# 1     2018   14h00  -15h00  Female          standing           N
# 2     2018           07h45    Male           surfing           N
# 6     2018  Late afternoon    Male          swimming           Y
# 8     2018           17h00    Male           walking           N
# ...    ...             ...     ...               ...         ...
# 6105  1826     19h00-20h00    Male  jumped overboard           Y
# 6113  1817         Evening    Male          swimming           Y
# 6114  1817         Evening    Male          swimming           Y
# 6115  1817           13h00    Male       conch diver           N
# 6160  1703           Night    Male          swimming           N
#
#                                                  Injury
# 0     No injury to occupant, outrigger canoe and pad...
# 1                            Minor injury to left thigh
# 2          Injury to left lower leg from surfboard skeg
# 6                                                 FATAL
# 8                                 Lower left leg bitten
# ...                                                 ...
# 6105                                              FATAL
# 6113                                              FATAL
# 6114                                              FATAL
# 6115                                     Abdomen bitten
# 6160  Hand and foot severely bitten, surgically ampu...
#
# [2647 rows x 6 columns]

# %%
data = shark_columns_copy

# %%
data
# Out:
#       Year            Time     Sex          Activity Fatal (Y/N)  \
# 0     2018           18h00  Female          paddling           N
# 1     2018   14h00  -15h00  Female          standing           N
# 2     2018           07h45    Male           surfing           N
# 6     2018  Late afternoon    Male          swimming           Y
# 8     2018           17h00    Male           walking           N
# ...    ...             ...     ...               ...         ...
# 6105  1826     19h00-20h00    Male  jumped overboard           Y
# 6113  1817         Evening    Male          swimming           Y
# 6114  1817         Evening    Male          swimming           Y
# 6115  1817           13h00    Male       conch diver           N
# 6160  1703           Night    Male          swimming           N
#
#                                                  Injury
# 0     No injury to occupant, outrigger canoe and pad...
# 1                            Minor injury to left thigh
# 2          Injury to left lower leg from surfboard skeg
# 6                                                 FATAL
# 8                                 Lower left leg bitten
# ...                                                 ...
# 6105                                              FATAL
# 6113                                              FATAL
# 6114                                              FATAL
# 6115                                     Abdomen bitten
# 6160  Hand and foot severely bitten, surgically ampu...
#
# [2647 rows x 6 columns]

# %%
time_column_dtype = data['Time'].dtypes
time_column_dtype
# Out:
# dtype('O')

# %%
data['Time'] = data['Time'].str.extract(r'(\d{1,2}:\d{1,2}|\d{1,2}h\d{1,2})', expand=False)
#I extracted the wrong data of the data frame in the column time and just keeping an exact time give in the format hhmm

# %%
data
# Out:
#       Year   Time     Sex          Activity Fatal (Y/N)  \
# 0     2018  18h00  Female          paddling           N
# 1     2018  14h00  Female          standing           N
# 2     2018  07h45    Male           surfing           N
# 6     2018    NaN    Male          swimming           Y
# 8     2018  17h00    Male           walking           N
# ...    ...    ...     ...               ...         ...
# 6105  1826  19h00    Male  jumped overboard           Y
# 6113  1817    NaN    Male          swimming           Y
# 6114  1817    NaN    Male          swimming           Y
# 6115  1817  13h00    Male       conch diver           N
# 6160  1703    NaN    Male          swimming           N
#
#                                                  Injury
# 0     No injury to occupant, outrigger canoe and pad...
# 1                            Minor injury to left thigh
# 2          Injury to left lower leg from surfboard skeg
# 6                                                 FATAL
# 8                                 Lower left leg bitten
# ...                                                 ...
# 6105                                              FATAL
# 6113                                              FATAL
# 6114                                              FATAL
# 6115                                     Abdomen bitten
# 6160  Hand and foot severely bitten, surgically ampu...
#
# [2647 rows x 6 columns]

# %%
data.dropna(subset=['Time'], inplace=True)
#we now take out the mssing values

# %%
data
# Out:
#       Year   Time     Sex                           Activity Fatal (Y/N)  \
# 0     2018  18h00  Female                           paddling           N
# 1     2018  14h00  Female                           standing           N
# 2     2018  07h45    Male                            surfing           N
# 8     2018  17h00    Male                            walking           N
# 9     2018  14h00    Male                           standing           N
# ...    ...    ...     ...                                ...         ...
# 6021  1852  01h50    Male  wreck of the steamship birkenhead           Y
# 6065  1841  14h00    Male                            bathing           Y
# 6091  1830  17h00    Male                            bathing           Y
# 6105  1826  19h00    Male                   jumped overboard           Y
# 6115  1817  13h00    Male                        conch diver           N
#
#                                                  Injury
# 0     No injury to occupant, outrigger canoe and pad...
# 1                            Minor injury to left thigh
# 2          Injury to left lower leg from surfboard skeg
# 8                                 Lower left leg bitten
# 9                                  Minor injury to foot
# ...                                                 ...
# 6021  FATAL. All of the women & children on board su...
# 6065                                              FATAL
# 6091                                              FATAL
# 6105                                              FATAL
# 6115                                     Abdomen bitten
#
# [2151 rows x 6 columns]

# %%
"""
Now the questions will be visualized one by one with their,
specific columns.

"""
# Out:
# '\nNow the questions will be visualized one by one with their,\nspecific columns.\n\n'

# %% [markdown]
# <h2>Which gender is tastier?

# %%
gender_attack = data['Sex'].value_counts()

# %%
gender_attack.plot(kind='bar', color= ['blue', 'pink'])
plt.xlabel('Gender')
plt.ylabel('Number of shark attacks')
plt.title('Shark attacks  victims by gender')
plt.xticks(rotation=0)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
"""
After plotting the data we see it was not completly clean.
there are two answers that had to be cleaned 'M' and 'lli'
"""
# Out:
# "\nAfter plotting the data we see it was not completly clean.\nthere are two answers that had to be cleaned 'M' and 'lli'\n"

# %%
scientific_genders = ['Male', 'Female']
data = data[data['Sex'].isin(scientific_genders)]

# %%
data
# Out:
#       Year   Time     Sex                           Activity Fatal (Y/N)  \
# 0     2018  18h00  Female                           paddling           N
# 1     2018  14h00  Female                           standing           N
# 2     2018  07h45    Male                            surfing           N
# 8     2018  17h00    Male                            walking           N
# 9     2018  14h00    Male                           standing           N
# ...    ...    ...     ...                                ...         ...
# 6021  1852  01h50    Male  wreck of the steamship birkenhead           Y
# 6065  1841  14h00    Male                            bathing           Y
# 6091  1830  17h00    Male                            bathing           Y
# 6105  1826  19h00    Male                   jumped overboard           Y
# 6115  1817  13h00    Male                        conch diver           N
#
#                                                  Injury
# 0     No injury to occupant, outrigger canoe and pad...
# 1                            Minor injury to left thigh
# 2          Injury to left lower leg from surfboard skeg
# 8                                 Lower left leg bitten
# 9                                  Minor injury to foot
# ...                                                 ...
# 6021  FATAL. All of the women & children on board su...
# 6065                                              FATAL
# 6091                                              FATAL
# 6105                                              FATAL
# 6115                                     Abdomen bitten
#
# [2149 rows x 6 columns]

# %%
"""
Even if we do not see them there might be missing values
as we eliminated the other two that were wrong.
as those two answers are real attacks that we just don't know
we can either catalog them as unknow or take them out. 
In this case because there is only two and that won't make
much difference to the end results we will eliminate them 

"""
# Out:
# "\nEven if we do not see them there might be missing values\nas we eliminated the other two that were wrong.\nas those two answers are real attacks that we just don't know\nwe can either catalog them as unknow or take them out. \nIn this case because there is only two and that won't make\nmuch difference to the end results we will eliminate them \n\n"

# %%
data.loc[data['Sex'].notna(), 'Sex'] = data['Sex'].dropna()

# %%
gender_counts = data['Sex'].value_counts()

# %%
plt.figure(figsize=(4, 5))
gender_counts.plot(kind='pie', autopct='%1.1f%%', colors=['cyan', 'teal'])
plt.title('Gender Distribution in Shark Attack Incidents')
# Out:
# Text(0.5, 1.0, 'Gender Distribution in Shark Attack Incidents')

# %% [markdown]
# <h4> Have sharks entered a pro-vegan movement

# %%
data = data[data['Year'] <= 2023]

# %%
missing_values= data.isnull().any()
print(missing_values)
# Out:
# Year           False
# Time           False
# Sex            False
# Activity       False
# Fatal (Y/N)    False
# Injury         False
# dtype: bool

# %%
year_attack = data['Year'].value_counts().sort_index()

# %%
data = data.sort_values(by='Year')

# %%
plt.figure(figsize=(8, 6))
year_attack.plot(kind='line', color= ['blue'])
plt.xlabel('Year')
plt.ylabel('Number of shark attacks')
plt.title('Shark attacks through the years')
plt.grid(True)

# %% [markdown]
# <h2> Do sharks procrastinate their lunchtime

# %%
print(data['Time'])
# Out:
# 6115    13h00
# 6105    19h00
# 6091    17h00
# 6065    14h00
# 6021    01h50
#         ...
# 43      18h00
# 48      15h30
# 49      15h01
# 24      09h40
# 0       18h00
# Name: Time, Length: 2149, dtype: object

# %%
data['Hour'] = data['Time'].str.extract(r'(\d{2})').astype(int)

# %%
hourly_counts = data['Hour'].value_counts().sort_index()

# %%
plt.figure(figsize=(9, 6))
plt.plot(hourly_counts.index, hourly_counts.values, marker='o', linestyle='-')
plt.xlabel('Hour of the Day')
plt.ylabel('Number of Shark Attacks')
plt.title('Distribution of Shark Attacks by Hour of the Day')
plt.grid(axis='y', linestyle='-', alpha=0.9)
plt.grid(axis='x', linestyle='--', alpha=0.9)

plt.show()

# %% [markdown]
# <h2> Do sharks like to bully humans?

# %%
print(data['Fatal (Y/N)'])
# Out:
# 6115    N
# 6105    Y
# 6091    Y
# 6065    Y
# 6021    Y
#        ..
# 43      N
# 48      N
# 49      N
# 24      N
# 0       N
# Name: Fatal (Y/N), Length: 2149, dtype: object

# %%
print(data['Injury'])
# Out:
# 6115                                       Abdomen bitten
# 6105                                                FATAL
# 6091                                                FATAL
# 6065                                                FATAL
# 6021    FATAL. All of the women & children on board su...
#                               ...
# 43                       Collision / No injury, no attack
# 48                            Injuries to abdomen and arm
# 49                      Severe laceration to left forearm
# 24                       No injury, shark bit hole in ski
# 0       No injury to occupant, outrigger canoe and pad...
# Name: Injury, Length: 2149, dtype: object

# %%
data["Fatal (Y/N)"].value_counts().plot(kind="bar",color="salmon",title="Number of fatalities")
plt.xticks(rotation=0.5)
plt.xlabel('Fatalities(Yes/No)')
plt.ylabel('Number of Shark Attacks')
plt.grid(axis='y', linestyle='--', alpha= 0.4)

# %%
"""
In this case as well we can observe that some of the data of the
column might have been wrong introduced. In this specific as the data
is so little and won't make any changes on the final result we can 
just keep the 'N' and 'Y' that have been written correctly in the data set.
Due to correcting later the graph before also corrected itself with the right values.
but lets leave it there as a reminder of how i found they were wrong values in the column that still had to deleted.

"""
# Out:
# "\nIn this case as well we can observe that some of the data of the\ncolumn might have been wrong introduced. In this specific as the data\nis so little and won't make any changes on the final result we can \njust keep the 'N' and 'Y' that have been written correctly in the data set.\nDue to correcting later the graph before also corrected itself with the right values.\nbut lets leave it there as a reminder of how i found they were wrong values in the column that still had to deleted.\n\n"

# %%
fatality_answrs = ['Y', 'N']
data = data[data['Fatal (Y/N)'].isin(fatality_answrs)]

# %%
data.loc[data['Fatal (Y/N)'].notna(),'Fatal (Y/N)'] = data['Fatal (Y/N)'].dropna()

# %%
data["Fatal (Y/N)"].value_counts().plot(kind="bar",color=["tan" , "rosybrown"],title="Number of fatalities")
plt.xticks(rotation=0.5)
plt.grid(axis='y', linestyle='--', alpha= 0.4)

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

shark = pd.read_csv(r"C:/Users/Marco/Desktop/IronHack/projects/Project_1/data/attacks.csv", encoding='latin1')


def clean(shark):
    
    shark.dropna(subset=['Year', 'Time', 'Sex ', 'Activity', 'Fatal (Y/N)', 'Injury'], inplace=True)
#eliminating all the missing values from the columns i will use
    shark.rename(columns={'Sex ': 'Sex'}, inplace=True)
#changing the sex column name because it had an unnecessary space at the end
    used_columns = ['Year', 'Time', 'Sex', 'Activity', 'Fatal (Y/N)', 'Injury']
    shark_columns = shark[used_columns]
#creating a new data frame with only the columns i need for my investigation
    shark_columns = shark_columns[shark_columns['Year'] > 1000] 
#I am taking out any year that is smaller than 1000 to take out from the year column wrong data

#to now do all the cleaning loc function is required to not;
#the original data set and to not get the error 'setting with copy warning'

    shark_columns.loc[shark['Sex'].isin(['M', 'F']), 'Sex'] = shark_columns['Sex'].replace({'M': 'Male', 'F': 'Female'})
#changing the original dataframe, to make it more readable i change the f by female and M by Male

    shark_columns.loc[:, 'Activity'] = shark_columns['Activity'].str.lower()
#making all the answers of the activity column with no capitalaized letters in case there are any irregularities
    shark_columns.loc[:, 'Activity'] = shark_columns['Activity'].str.lower()
#making all the answers of the activity column with no capitalaized letters in case there are any irregularities

    shark_columns_copy = shark_columns.copy()
    shark_columns_copy['Year'] = shark_columns_copy['Year'].astype(str).str.split('.').str[0].astype(int)
#creating a copy due to error of modifying the original data frame
#converting all the data in the year column into integrers

    data = shark_columns_copy
    
    time_column_dtype = data['Time'].dtypes
    time_column_dtype
    
    data['Time'] = data['Time'].str.extract(r'(\d{1,2}:\d{1,2}|\d{1,2}h\d{1,2})', expand=False)
#I extracted the wrong data of the data frame in the column time and just keeping an exact time give in the format hhmm

    data.dropna(subset=['Time'], inplace=True)
#we now take out the mssing values
    
    return data
    
df = clean(shark)

# %%
df
# Out:
#       Year   Time     Sex                           Activity Fatal (Y/N)  \
# 0     2018  18h00  Female                           paddling           N
# 1     2018  14h00  Female                           standing           N
# 2     2018  07h45    Male                            surfing           N
# 8     2018  17h00    Male                            walking           N
# 9     2018  14h00    Male                           standing           N
# ...    ...    ...     ...                                ...         ...
# 6021  1852  01h50    Male  wreck of the steamship birkenhead           Y
# 6065  1841  14h00    Male                            bathing           Y
# 6091  1830  17h00    Male                            bathing           Y
# 6105  1826  19h00    Male                   jumped overboard           Y
# 6115  1817  13h00    Male                        conch diver           N
#
#                                                  Injury
# 0     No injury to occupant, outrigger canoe and pad...
# 1                            Minor injury to left thigh
# 2          Injury to left lower leg from surfboard skeg
# 8                                 Lower left leg bitten
# 9                                  Minor injury to foot
# ...                                                 ...
# 6021  FATAL. All of the women & children on board su...
# 6065                                              FATAL
# 6091                                              FATAL
# 6105                                              FATAL
# 6115                                     Abdomen bitten
#
# [2151 rows x 6 columns]

# %% [markdown]
# <h2>Which gender is tastier?

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

def tasty_test(df):
    
    shark = pd.read_csv(r"C:/Users/Marco/Desktop/IronHack/projects/Project_1/data/attacks.csv", encoding='latin1')    
    gender_attack = df['Sex'].value_counts()
    
    gender_attack.plot(kind='bar',color=['cyan', 'teal'])
    plt.xlabel('Gender')
    plt.ylabel('Number of shark attacks')
    plt.title('Gender Distribution in Shark Attack Incidents')
    plt.xticks(rotation=0)
    plt.show()
test_1=tasty_test(df)

"""
After plotting the data we see it was not completly clean.
there are two answers that had to be cleaned 'M' and 'lli'
"""
# Out:
# "\nAfter plotting the data we see it was not completly clean.\nthere are two answers that had to be cleaned 'M' and 'lli'\n"

# %%
"""
Even if we do not see them there might be missing values
as we eliminated the other two that were wrong.
as those two answers are real attacks that we just don't know
we can either catalog them as unknow or take them out. 
In this case because there is only two and that won't make
much difference to the end results we will eliminate them 

"""
# Out:
# "\nEven if we do not see them there might be missing values\nas we eliminated the other two that were wrong.\nas those two answers are real attacks that we just don't know\nwe can either catalog them as unknow or take them out. \nIn this case because there is only two and that won't make\nmuch difference to the end results we will eliminate them \n\n"

# %%
def tasty(df):
    shark = pd.read_csv(r"C:/Users/Marco/Desktop/IronHack/projects/Project_1/data/attacks.csv", encoding='latin1')    
    gender_attack = df['Sex'].value_counts()
    
    scientific_genders = ['Male', 'Female']
    df = df[df['Sex'].isin(scientific_genders)]

    df.loc[df['Sex'].notna(), 'Sex'] = df['Sex'].dropna()
    gender_counts = df['Sex'].value_counts()
    
    gender_counts.plot(kind='pie', autopct='%1.1f%%', colors=['cyan', 'teal'])
    plt.title('Gender Distribution in Shark Attack Incidents')
    plt.show()
    
tasty(df)

# %% [markdown]
# <h2> Have sharks entered a pro-vegan movement

# %%
def vegan(df):
    shark = pd.read_csv(r"C:/Users/Marco/Desktop/IronHack/projects/Project_1/data/attacks.csv", encoding='latin1')    
    
    df = df[df['Year'] <= 2023]
    
    year_attack = df['Year'].value_counts().sort_index()
    df = df.sort_values(by='Year')
    
    plt.figure(figsize=(8, 6))
    year_attack.plot(kind='line', color= ['blue'])
    plt.xlabel('Year')
    plt.ylabel('Number of shark attacks')
    plt.title('Shark attacks through the years')
    plt.grid(True)
    
vegan(df)

# %% [markdown]
# <h2> Do sharks procrastinate their lunchtime

# %%
def procastinate(df):
    
    shark = pd.read_csv(r"C:/Users/Marco/Desktop/IronHack/projects/Project_1/data/attacks.csv", encoding='latin1')    
    
    df['Hour'] = df['Time'].str.extract(r'(\d{2})').astype(int)
    hourly_counts = df['Hour'].value_counts().sort_index()
    
    plt.figure(figsize=(9, 6))
    plt.plot(hourly_counts.index, hourly_counts.values, marker='o', linestyle='-')
    plt.xlabel('Hour of the Day')
    plt.ylabel('Number of Shark Attacks')
    plt.title('Distribution of Shark Attacks by Hour of the Day')
    plt.grid(axis='y', linestyle='-', alpha=0.9)
    plt.grid(axis='x', linestyle='--', alpha=0.9)

    plt.show()

    
procastinate(df)

# %% [markdown]
# <h2> Do sharks like to bully humans?

# %%
def death_test(df):
    
    shark = pd.read_csv(r"C:/Users/Marco/Desktop/IronHack/projects/Project_1/data/attacks.csv", encoding='latin1')  
    
    df["Fatal (Y/N)"].value_counts().plot(kind="bar",color="salmon",title="Number of fatalities")
    plt.xticks(rotation=0.5)
    plt.xlabel('Fatalities(Yes/No)')
    plt.ylabel('Number of Shark Attacks')
    plt.grid(axis='y', linestyle='--', alpha= 0.4)
    
lunch_test(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 11
#       8     plt.ylabel('Number of Shark Attacks')
#       9     plt.grid(axis='y', linestyle='--', alpha= 0.4)
# ---> 11 lunch_test(df)
#
# NameError: name 'lunch_test' is not defined

# %%
"""
In this case as well we can observe that some of the data of the
column might have been wrong introduced. In this specific as the data
is so little and won't make any changes on the final result we can 
just keep the 'N' and 'Y' that have been written correctly in the data set.
Due to correcting later the graph before also corrected itself with the right values.
but lets leave it there as a reminder of how i found they were wrong values in the column that still had to deleted.

"""
# Out:
# "\nIn this case as well we can observe that some of the data of the\ncolumn might have been wrong introduced. In this specific as the data\nis so little and won't make any changes on the final result we can \njust keep the 'N' and 'Y' that have been written correctly in the data set.\nDue to correcting later the graph before also corrected itself with the right values.\nbut lets leave it there as a reminder of how i found they were wrong values in the column that still had to deleted.\n\n"

# %%
def death(df):
    shark = pd.read_csv(r"C:/Users/Marco/Desktop/IronHack/projects/Project_1/data/attacks.csv", encoding='latin1') 
    
    fatality_answrs = ['Y', 'N']
    df = df[df['Fatal (Y/N)'].isin(fatality_answrs)]
    
    df.loc[df['Fatal (Y/N)'].notna(),'Fatal (Y/N)'] = df['Fatal (Y/N)'].dropna()
    
    df["Fatal (Y/N)"].value_counts().plot(kind="bar",color=["tan" , "rosybrown"],title="Number of fatalities")
    plt.xticks(rotation=0.5)
    plt.grid(axis='y', linestyle='--', alpha= 0.4)
    
death(df)
